# %%
from tools import *
from odes import *

# %%
class Room(ODE):
    def __init__(self, notation):
        super().__init__(notation=notation)
        self.state = TEMP_NIGHT_NOMINAL
        self.open = False

    def dy_dt(self, t):
        radiator_power = K_RADIATOR * A_RADIATOR * (radiator.state - self.state)
        wall_loss_rate = A_WALL * K_WALL * (self.state - env.state)
        window_loss_rate = A_WINDOW * {False: U.wi_closed, True: U.wi_open}[self.open] * (self.state - env.state)
        self.rate = (radiator_power - window_loss_rate - wall_loss_rate) / (C_AIR * D_AIR * V_ROOM)
        return self.rate

    def dy_dt2(self, t):
        q_wi = (self.state - env.state) * A_WINDOW * {False: U.wi_closed, True: U.wi_open}[self.open]  # windows lows wate
        q_wa = (self.state - env.state) * A_ROOF * U.wa
        q_ro = (self.state - env.state) * A_ROOF * U.ro
        self.dq = radiator.dq - q_wi - q_wa - q_ro
        self.rate = self.dq / (C_AIR * D_AIR * V_ROOM)
        return self.rate

# %%
class Radiator(ODE):
    def __init__(self, notation, hyst = 1):
        super().__init__(notation=notation)
        self.on: bool = False
        self.state = TEMP_NIGHT_NOMINAL
        self.hyst = hyst

    def dy_dt(self, t):
        opening = self.opening()
        self.dq = (self.state - room.state) * A_RADIATOR * U.he
        dt_gain = opening * F_WATER * (boiler.state - self.state) / V_RADIATOR
        dt_loss = self.dq / (D_AIR * C_WATER * V_RADIATOR)
        self.rate = dt_gain - dt_loss
        return self.rate

    def opening(self):
        temp_diff =  self.state - room.state

        if temp_diff < 0:
            return 0

        if temp_diff >= self.hyst:
            return 1

        return temp_diff/self.hyst

# %%
main_event = Event(name='main_event', time=8**8, repeat=5 * TimeUnits.minute)
per_minute = Event(name='pm_event', time=2**2, repeat=TimeUnits.minute)
per_3second = Event(name='pm_event', time=3**3, repeat=TimeUnits.minute)
per_5_minute = Event(name='pm_event', time=4**4, repeat=5 * TimeUnits.minute)
per_10_minute = Event(name='pm_event', time=5**5, repeat=10 * TimeUnits.minute)
per_quarter = Event(name='pm_event', time=6**6, repeat=15 * TimeUnits.minute)
per_hour = Event(name='ph_event', time=7**7, repeat=TimeUnits.hour)

# %% [markdown]
# #### Calendar

# %%
wake_up = Event(name='wake_up', time=7 * TimeUnits.hour + 2, repeat=24 * TimeUnits.hour)
time_to_sleep = Event(name='time_to_sleep', time=22 * TimeUnits.hour + 123, repeat=24 * TimeUnits.hour)

# %%
open_window = Event(name='open_window', time=7.10 * TimeUnits.hour)
close_window = Event(name='close_window', time=10 * TimeUnits.hour)

# %%
ow1 = Event(name='open_window', time=10.5 * TimeUnits.hour)
cw1 = Event(name='close_window', time=13 * TimeUnits.hour)

ow2 = Event(name='open_window', time=14 * TimeUnits.hour)
cw2 = Event(name='close_window', time=15 * TimeUnits.hour)

ow3 = Event(name='open_window', time=17 * TimeUnits.hour)
cw3 = Event(name='close_window', time=18 * TimeUnits.hour)

ow4 = Event(name='open_window', time=20 * TimeUnits.hour)
cw4 = Event(name='close_window', time=21 * TimeUnits.hour)

ow5 = Event(name='open_window', time=22 * TimeUnits.hour)
cw5 = Event(name='close_window', time=22.5 * TimeUnits.hour)

cw_ow_events = [
    ow1, ow2, ow3, ow4,  ow5, cw1, cw2, cw3, cw4,  cw5,
]

# %%
def update_integrator(ode, **kwargs):
    kwargs['ics'][ode.notation] = ode.state
    kwargs['params'][f'{ode.notation}_rate'] = ode.rate

# %%
def update_rate(ode, **kwargs):
    ode.state = kwargs['c_step']['points'][ode.notation][-1]
    ode.dy_dt(t=kwargs['t'][-1])

# %%
def clb_env_temp(**kwargs):
    env.state = env.compute_temp(t=kwargs['t'][-1])
    env.dy_dt(t=kwargs['t'][-1])
    update_integrator(ode=env, **kwargs)
    # update_rate(ode=radiator, **kwargs)

# %%
def clb_room_temp(**kwargs):
    update_rate(ode=room, **kwargs)
    update_integrator(ode=room, **kwargs)

# %%
def clb_radiator_temp(**kwargs):
    update_rate(ode=radiator, **kwargs)
    update_integrator(ode=radiator, **kwargs)
    # print(radiator.state)
    pass

# %%
def clb_wake_up(**kwargs):
    radiator.state = TEMP_DAY_NOMINAL
    # radiator.dy_dt(t=kwargs['t'][-1])
    update_integrator(ode=radiator, **kwargs)
    print(f'Waking up')

# %%
def clb_sleep(**kwargs):
    radiator.state = TEMP_NIGHT_NOMINAL
    # radiator.dy_dt(t=kwargs['t'][-1])
    update_integrator(ode=radiator, **kwargs)

# %%
def clb_toggle_window(**kwargs):
    room.open = not room.open

# %%
def clb_open_window(**kwargs):
    room.open = True

# %%
def clb_close_window(**kwargs):
    room.open = False

# %%
def clb_log_callback(**kwargs):
    info = lambda ode: {'state': ode.state, 'rate': ode.rate}
    time_ = kwargs['c_step']['points']['t'][-1]
    information = {
        'room': info(room),
        'radiator': {**info(radiator), 'opening': radiator.opening()},
    }
    print([time_/3600, time_, integrator.tdata[-1]])
    print(information, '\n')

# %%
for e in cw_ow_events:
    if 'open' in e.name:
        e.attach_callback(clb_open_window)
    else:
        e.attach_callback(clb_close_window)

# %%
main_event.attach_callback(func=clb_env_temp)
main_event.attach_callback(func=clb_log_callback)
main_event.attach_callback(func=clb_room_temp)
# main_event.attach_callback(func=clb_radiator_temp)
wake_up.attach_callback(func=clb_wake_up)
time_to_sleep.attach_callback(func=clb_sleep)

# %%
TEMP_NIGHT_NOMINAL = 15
TEMP_DAY_NOMINAL = 22
BOILER_WATER_TEMP = 40
EXPERIMENT_DURATION = TimeUnits.day

# %%
room = Room(notation='room')
env = Environment(notation='env')
boiler = Boiler(notation='boiler')
radiator = Radiator(notation='radiator', hyst=1)

# %%
integrator = Integrator(
    expressions={**env.expr, **boiler.expr, **radiator.expr, **room.expr},
    ics={**env.ics, **boiler.ics, **radiator.ics, **room.ics},
    events=[
        wake_up,
        time_to_sleep,
        main_event,
    ],
    tdata=[0, TimeUnits.day],
    params={
        'env_rate': env.dy_dt(t=0),
        'boiler_rate': boiler.dy_dt(t=0),
        'radiator_rate': radiator.dy_dt(t=0),
        'room_rate': room.dy_dt(t=0),
    },
    max_step=10 * TimeUnits.hour,
    init_step=TimeUnits.minute/2
)
integrator.verbose = 2

# %%
with timer() as f:
    results = integrator.solve()
    print(type(results))

list(results)
# Out:
# calling: clb_env_temp
# calling: clb_log_callback
# [0.08777777779133311, 316.0000000487992, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [0.17111111111496638, 616.000000013879, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [0.25444444444563835, 916.000000004298, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [0.3377777777911906, 1216.0000000482862, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [0.4211111111226774, 1516.0000000416387, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [0.5044444444497836, 1816.0000000192213, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [0.5877777777935277, 2116.0000000566997, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [0.6711111111180805, 2416.00000002509, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [0.7544444444677357, 2716.0000000838486, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [0.8377777777960379, 3016.0000000657365, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [0.9211111111370316, 3316.0000000933137, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [1.0044444444685434, 3616.0000000867562, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [1.0877777777808622, 3916.0000000111036, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [1.1711111111110275, 4215.999999999699, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [1.2544444444472191, 4516.000000009989, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [1.337777777804252, 4816.000000095308, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [1.4211111111280479, 5116.0000000609725, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [1.504444444446346, 5416.000000006846, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [1.587777777779811, 5716.00000000732, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [1.6711111111149317, 6016.000000013754, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [1.7544444444453382, 6316.000000003218, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [1.8377777777788136, 6616.000000003729, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [1.9211111111374533, 6916.000000094832, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [2.0044444444553715, 7216.0000000393375, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [2.0877777777841673, 7516.000000023002, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [2.171111111121944, 7816.000000038998, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [2.254444444447893, 8116.000000012415, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [2.3377777777909032, 8416.000000047252, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [2.421111111127154, 8716.000000057755, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [2.5044444444488607, 9016.000000015898, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [2.5877777777986197, 9316.000000075031, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [2.671111111132849, 9616.000000078257, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [2.7544444444589917, 9916.00000005237, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [2.8377777778014295, 10216.000000085147, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [2.9211111111333747, 10516.000000080148, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [3.004444444445652, 10816.000000004347, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [3.087777777781059, 11116.000000011813, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [3.1711111111319847, 11416.000000075144, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [3.254444444447728, 11716.00000001182, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [3.3377777777784097, 12016.000000002276, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [3.4211111111177672, 12316.000000023962, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [3.5044444444514964, 12616.000000025388, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [3.5877777777780926, 12916.000000001133, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [3.671111111122784, 13216.000000042022, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [3.7544444444489415, 13516.000000016189, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [3.837777777802118, 13816.000000087624, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [3.9211111111119514, 14116.000000003025, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [4.004444444466226, 14416.000000078415, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [4.087777777803185, 14716.000000091466, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [4.171111111117433, 15016.000000022761, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [4.254444444460079, 15316.000000056285, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [4.337777777802252, 15616.000000088106, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [4.421111111110964, 15915.999999999469, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [4.504444444458816, 16216.000000051736, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [4.587777777791698, 16516.000000050113, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [4.671111111114177, 16816.000000011038, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [4.7544444444691685, 17116.000000089007, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [4.837777777781092, 17416.000000011933, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [4.9211111111163905, 17716.000000019005, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [5.004444444464775, 18016.00000007319, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [5.087777777787834, 18316.0000000362, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [5.171111111135743, 18616.000000088676, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [5.254444444449261, 18916.00000001734, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [5.337777777799777, 19216.000000079195, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [5.421111111116, 19516.0000000176, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [5.504444444458336, 19816.00000005001, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [5.587777777779739, 20116.00000000706, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [5.671111111131656, 20416.00000007396, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [5.754444444459193, 20716.000000053096, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [5.83777777777977, 21016.000000007174, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [5.921111111121873, 21316.000000038744, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [6.004444444464117, 21616.000000070824, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [6.08777777777705, 21915.99999999738, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [6.171111111133104, 22216.000000079177, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [6.254444444467656, 22516.00000008356, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [6.337777777785238, 22816.000000026856, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [6.421111111125717, 23116.000000052583, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [6.504444444462334, 23416.000000064403, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [6.5877777777778395, 23716.000000000222, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [6.67111111111298, 24016.000000006727, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [6.754444444450801, 24316.000000022883, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [6.837777777779147, 24616.00000000493, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [6.921111111118713, 24916.00000002737, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_wake_up
# Waking up
# calling: clb_env_temp
# calling: clb_log_callback
# [7.087777777789662, 25516.000000042783, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [7.171111111114015, 25816.000000010452, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [7.254444444459225, 26116.000000053213, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [7.337777777796383, 26416.00000006698, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [7.421111111134446, 26716.00000008401, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [7.50444444445948, 27016.00000005413, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [7.5877777777835025, 27316.00000002061, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [7.671111111124806, 27616.000000049302, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [7.754444444454235, 27916.000000035245, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [7.837777777778396, 28216.000000002226, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [7.921111111120008, 28516.00000003203, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [8.004444444450527, 28816.0000000219, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [8.08777777779397, 29116.000000058295, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [8.17111111112526, 29416.000000050935, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [8.254444444446756, 29716.000000008324, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [8.337777777796108, 30016.00000006599, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [8.421111111117435, 30316.000000022766, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [8.504444444447516, 30616.00000001106, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [8.58777777779357, 30916.000000056854, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [8.6711111111142, 31216.00000001112, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [8.754444444450789, 31516.00000002284, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [8.837777777784927, 31816.000000025735, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [8.92111111112896, 32116.000000064254, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [9.004444444445259, 32416.000000002932, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [9.087777777798285, 32716.00000007383, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [9.171111111116398, 33016.000000019034, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [9.25444444446747, 33316.000000082895, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [9.337777777786412, 33616.00000003108, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [9.421111111116687, 33916.000000020074, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [9.504444444447438, 34216.000000010776, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [9.587777777790663, 34516.000000046384, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [9.671111111121407, 34816.000000037064, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [9.754444444454968, 35116.000000037886, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [9.837777777787075, 35416.00000003347, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [9.921111111130104, 35716.00000006837, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [10.004444444446682, 36016.000000008054, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [10.087777777788686, 36316.00000003927, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [10.171111111128054, 36616.000000060994, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [10.254444444461932, 36916.00000006295, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [10.33777777778063, 37216.00000001027, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [10.421111111110992, 37515.99999999957, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [10.504444444457091, 37816.000000045526, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [10.58777777778233, 38116.000000016385, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [10.671111111128425, 38416.00000006233, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [10.754444444460393, 38716.000000057415, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [10.837777777779078, 39016.00000000468, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [10.92111111113056, 39316.00000007002, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [11.004444444444786, 39616.00000000123, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [11.087777777785261, 39916.00000002694, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [11.171111111118977, 40216.00000002832, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [11.254444444463699, 40516.00000006932, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [11.337777777795258, 40816.00000006293, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [11.421111111119574, 41116.000000030464, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [11.504444444448604, 41416.000000014974, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [11.587777777783453, 41716.00000002043, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [11.671111111131843, 42016.00000007464, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [11.754444444457292, 42316.00000004625, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [11.837777777799577, 42616.00000007848, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [11.921111111114357, 42916.000000011685, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [12.004444444448872, 43216.00000001594, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [12.087777777781746, 43516.00000001428, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [12.171111111116886, 43816.00000002079, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [12.254444444447067, 44116.000000009444, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [12.337777777786249, 44416.00000003049, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [12.421111111133525, 44716.00000008069, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [12.504444444464852, 45016.000000073465, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [12.587777777779676, 45316.00000000683, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [12.671111111113278, 45616.0000000078, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [12.754444444446722, 45916.0000000082, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [12.837777777788515, 46216.00000003866, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [12.92111111111922, 46516.00000002919, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [13.004444444446067, 46816.00000000584, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [13.087777777782252, 47116.00000001611, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [13.171111111126601, 47416.00000005576, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [13.254444444443699, 47715.999999997315, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [13.337777777781113, 48016.000000012005, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [13.421111111112687, 48316.000000005675, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [13.50444444445668, 48616.00000004405, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [13.587777777788316, 48916.00000003794, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [13.671111111124201, 49216.00000004713, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [13.754444444469774, 49516.00000009119, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [13.83777777779484, 49816.00000006142, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [13.921111111112275, 50116.00000000419, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [14.004444444453943, 50416.0000000342, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [14.087777777778923, 50716.000000004125, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [14.171111111122144, 51016.00000003972, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [14.254444444468913, 51316.00000008808, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [14.337777777801811, 51616.00000008652, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [14.421111111113609, 51916.00000000899, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [14.504444444454803, 52216.00000003729, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [14.587777777783064, 52516.00000001903, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [14.671111111122228, 52816.00000004002, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [14.754444444447167, 53116.0000000098, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [14.83777777778221, 53416.000000015956, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [14.921111111128551, 53716.000000062784, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [15.004444444454608, 54016.00000003659, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [15.087777777789801, 54316.000000043285, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [15.171111111113243, 54616.000000007676, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [15.254444444449469, 54916.00000001809, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [15.337777777793303, 55216.00000005589, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [15.421111111111635, 55516.000000001884, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [15.504444444448826, 55816.000000015774, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [15.587777777792937, 56116.00000005457, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [15.671111111115348, 56416.00000001525, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [15.754444444445493, 56716.000000003776, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [15.837777777802598, 57016.000000089356, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [15.92111111112954, 57316.00000006634, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [16.004444444468167, 57616.0000000854, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [16.08777777778581, 57916.00000002892, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [16.171111111112936, 58216.00000000656, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [16.2544444444487, 58516.00000001533, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [16.337777777778893, 58816.000000004016, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [16.421111111129893, 59116.000000067615, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [16.504444444453373, 59416.00000003214, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [16.587777777788062, 59716.00000003703, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [16.671111111114616, 60016.000000012624, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [16.7544444444472, 60316.00000000991, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [16.837777777790176, 60616.00000004463, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [16.921111111132582, 60916.0000000773, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [17.004444444445927, 61216.00000000533, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [17.08777777778127, 61516.00000001257, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [17.171111111129647, 61816.000000066735, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [17.254444444459086, 62116.00000005271, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [17.337777777789785, 62416.00000004323, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [17.421111111136305, 62716.0000000907, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [17.504444444455455, 63016.00000003963, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [17.587777777778108, 63316.00000000119, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [17.6711111111127, 63616.00000000572, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [17.754444444458773, 63916.00000005158, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [17.837777777793054, 64216.000000055, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [17.921111111131438, 64516.00000007318, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [18.004444444454524, 64816.00000003629, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [18.087777777779586, 65116.00000000651, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [18.17111111111782, 65416.000000024156, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [18.25444444444917, 65716.00000001701, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [18.33777777778386, 66016.0000000219, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [18.421111111132515, 66316.00000007705, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [18.504444444448637, 66616.00000001509, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [18.587777777778037, 66916.00000000093, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [18.671111111113653, 67216.00000000915, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [18.754444444468128, 67516.00000008526, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [18.837777777792947, 67816.00000005461, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [18.921111111124684, 68116.00000004887, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [19.004444444450527, 68416.0000000219, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [19.087777777799083, 68716.0000000767, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [19.17111111111771, 69016.00000002376, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [19.254444444455746, 69316.00000004069, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [19.337777777801755, 69616.00000008632, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [19.421111111124624, 69916.00000004865, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [19.504444444455164, 70216.00000003859, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [19.587777777779014, 70516.00000000445, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [19.671111111119153, 70816.00000002894, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [19.75444444446813, 71116.00000008527, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [19.837777777784893, 71416.00000002561, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [19.921111111131054, 71716.0000000718, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [20.004444444466472, 72016.0000000793, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [20.087777777777955, 72316.00000000064, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [20.17111111113543, 72616.00000008756, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [20.254444444450055, 72916.0000000202, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [20.3377777777779, 73216.00000000045, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [20.42111111111371, 73516.00000000936, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [20.504444444459445, 73816.000000054, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [20.587777777781792, 74116.00000001445, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [20.67111111112193, 74416.00000003896, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [20.754444444448698, 74716.00000001531, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [20.83777777777962, 75016.00000000664, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [20.921111111123253, 75316.00000004371, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [21.004444444466333, 75616.0000000788, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [21.087777777781284, 75916.00000001262, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [21.17111111111873, 76216.00000002743, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [21.254444444466092, 76516.00000007793, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [21.337777777781902, 76816.00000001484, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [21.421111111129218, 77116.00000006518, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [21.504444444452858, 77416.00000003028, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [21.58777777777956, 77716.00000000642, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [21.671111111131623, 78016.00000007384, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [21.754444444451874, 78316.00000002675, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [21.83777777779142, 78616.00000004911, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [21.921111111112335, 78916.00000000441, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [22.0044444444644, 79216.00000007184, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 22, 'rate': 0.0, 'opening': 1}}
#
# calling: clb_sleep
# calling: clb_env_temp
# calling: clb_log_callback
# [22.087777777783963, 79516.00000002226, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [22.171111111123768, 79816.00000004556, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [22.25444444445046, 80116.00000002165, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [22.337777777779657, 80416.00000000677, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [22.421111111131605, 80716.00000007378, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [22.504444444456517, 81016.00000004347, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [22.58777777778989, 81316.0000000436, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [22.67111111112464, 81616.0000000487, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [22.75444444446778, 81916.00000008401, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [22.837777777778225, 82216.00000000162, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [22.921111111122276, 82516.00000004019, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [23.00444444446623, 82816.00000007843, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [23.08777777778297, 83116.0000000187, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [23.171111111135627, 83416.00000008826, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [23.25444444446194, 83716.00000006298, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [23.337777777802984, 84016.00000009075, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [23.421111111116645, 84316.00000001992, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [23.50444444445889, 84616.00000005201, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [23.58777777777906, 84916.00000000461, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [23.671111111119924, 85216.00000003172, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [23.754444444449828, 85516.00000001938, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [23.837777777786542, 85816.00000003155, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# calling: clb_env_temp
# calling: clb_log_callback
# [23.92111111111466, 86116.00000001278, 86400.0]
# {'room': {'state': 15, 'rate': -0.0008044482771935697}, 'radiator': {'state': 15, 'rate': 0.0, 'opening': 0.0}}
#
# <class 'box.config_box.ConfigBox'>
# duration: 2.04s
# ['boiler', 'env', 'radiator', 'room', 't', 'results', 'events']

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_event(event, color, obj):
    count = 0
    start = int(integrator.tdata[0] + event.time)
    end = int(integrator.tdata[1]) + 1
    dt = int(event.repeat)
    dt = 1 if dt == 0 else dt
    for _ in range(start, end, dt):
        if count == 0:
            obj.axvline(_/3600, color=color, label=event.name)
            count += 1
            continue
        obj.axvline(_/3600, color=color)

# %%
num = int(TimeUnits.hour) * 24
if results is not None:
    fig, ax = plt.subplots(4, 1, figsize=(40, 22))
    ax[0].plot(results['t']/3600, results['room'], '--', label='room')
    ax[1].plot(results['t']/3600, results['radiator'], '--', label='radiator')
    ax[2].plot(results['t']/3600, results['boiler'], '--', label='boiler')
    ax[3].plot(results['t']/3600, results['env'], '--', label='env')
    for _ in ax:
        plot_event(event=cw_ow_events[0], color='r', obj=_)
        plot_event(event=cw_ow_events[5], color='b', obj=_)
        plot_event(event=wake_up, color='g', obj=_)
        #plot_event(time_to_sleep, color='r', obj=_)
        #plot_event(per_5_hour, color='g', obj=_)
        # plot_event(close_window, color='y', obj=_)
        _.legend()        # plot_event(wake_up, color='b', obj=_)



    plt.tight_layout()
    plt.show()
